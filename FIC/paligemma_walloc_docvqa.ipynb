# %%
# !wget https://hf.co/danjacobellis/walloc/resolve/main/RGB_Li_12c_J3_nf8_v1.0.2.pth

# %%
# !wget https://hf.co/danjacobellis/walloc/resolve/main/RGB_Li_48c_J3_nf8_v1.0.2.pth

# %%
import io
import torch
import numpy as np
from transformers import AutoProcessor, PaliGemmaForConditionalGeneration
from PIL import Image
from datasets import load_dataset
from datasets import Image as HFImage
from anls_star import anls_score
from fastprogress.fastprogress import progress_bar
from torchvision.transforms import ToPILImage, PILToTensor
from walloc import walloc
class Config: pass

# %%
def walloc_compress(sample):
    with torch.no_grad():
        img = sample['image'].resize((896,896),resample=Image.Resampling.LANCZOS).convert("RGB")
        x = PILToTensor()(img).to(torch.float)
        x = (x/255 - 0.5).unsqueeze(0).to(device)
        H, W = x.size(2), x.size(3)
        x_padded = walloc.pad(x,p=8)
        X = codec.wavelet_analysis(x_padded,codec.J)
        Y = codec.encoder(X)
        X_hat = codec.decoder(Y)
        x_hat = codec.wavelet_synthesis(X_hat,codec.J)
        x_hat = codec.clamp(x_hat)        
        x_hat = walloc.crop(x_hat, (H,W))
        rec = ToPILImage()(x_hat[0] + 0.5)
        buff = io.BytesIO()
        rec.save(buff, format='WEBP', lossless=True)
        rec_webp_bytes = buff.getbuffer()   
    return {
        'image': rec_webp_bytes,
        'question': sample['question'],
        'questionId': sample['questionId'],
    }

# %%
ds = load_dataset("danjacobellis/docvqa",split='test')
# Out:
# Resolving data files:   0%|          | 0/57 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/57 [00:00<?, ?it/s]

# %%
device = "cuda"
checkpoints = [
    'RGB_Li_12c_J3_nf8_v1.0.2.pth',
    'RGB_Li_48c_J3_nf8_v1.0.2.pth'
]
fic_ds = []
for cf in checkpoints:
    checkpoint = torch.load(cf,map_location="cpu",weights_only=False)
    codec_config = checkpoint['config']
    codec = walloc.Codec2D(
        channels = codec_config.channels,
        J = codec_config.J,
        Ne = codec_config.Ne,
        Nd = codec_config.Nd,
        latent_dim = codec_config.latent_dim,
        latent_bits = codec_config.latent_bits,
        lightweight_encode = codec_config.lightweight_encode
    )
    codec.load_state_dict(checkpoint['model_state_dict'])
    codec = codec.to(device)
    codec.eval();
    fic_ds.append(
        ds.map(walloc_compress)
    )
# Out:
# Map:   0%|          | 0/5188 [00:00<?, ? examples/s]
# /home/dgj335/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Attempt to open cnn_infer failed: handle=0 error: libcudnn_cnn_infer.so.8: cannot open shared object file: No such file or directory (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:78.)
#   return F.conv2d(input, weight, bias, self.stride,

# %%
model_id = "google/paligemma-3b-ft-docvqa-896"
model = PaliGemmaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="cuda",
    revision="bfloat16",
)
processor = AutoProcessor.from_pretrained(model_id)
# Out:
# Resolving data files:   0%|          | 0/57 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/57 [00:00<?, ?it/s]
# /home/dgj335/.local/lib/python3.10/site-packages/transformers/models/paligemma/configuration_paligemma.py:137: FutureWarning: The `vocab_size` attribute is deprecated and will be removed in v4.44, Please use `text_config.vocab_size` instead.
#   warnings.warn(
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 3
#       1 ds = load_dataset("danjacobellis/docvqa",split='test')
#       2 model_id = "google/paligemma-3b-ft-docvqa-896"
# ----> 3 model = PaliGemmaForConditionalGeneration.from_pretrained(
#       4     model_id,
#       5     torch_dtype=torch.bfloat16,
#       6     device_map="cuda",
#       7     revision="bfloat16",
#       8 )
#       9 processor = AutoProcessor.from_pretrained(model_id)
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:3960, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3950     if dtype_orig is not None:
#    3951         torch.set_default_dtype(dtype_orig)
#    3953     (
#    3954         model,
#    3955         missing_keys,
#    3956         unexpected_keys,
#    3957         mismatched_keys,
#    3958         offload_index,
#    3959         error_msgs,
# -> 3960     ) = cls._load_pretrained_model(
#    3961         model,
#    3962         state_dict,
#    3963         loaded_state_dict_keys,  # XXX: rename?
#    3964         resolved_archive_file,
#    3965         pretrained_model_name_or_path,
#    3966         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3967         sharded_metadata=sharded_metadata,
#    3968         _fast_init=_fast_init,
#    3969         low_cpu_mem_usage=low_cpu_mem_usage,
#    3970         device_map=device_map,
#    3971         offload_folder=offload_folder,
#    3972         offload_state_dict=offload_state_dict,
#    3973         dtype=torch_dtype,
#    3974         hf_quantizer=hf_quantizer,
#    3975         keep_in_fp32_modules=keep_in_fp32_modules,
#    3976         gguf_path=gguf_path,
#    3977     )
#    3979 # make sure token embedding weights are still tied if needed
#    3980 model.tie_weights()
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:4434, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4430                 set_module_tensor_to_device(
#    4431                     model_to_load, key, "cpu", torch.empty(*param.size(), dtype=dtype)
#    4432                 )
#    4433     else:
# -> 4434         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4435             model_to_load,
#    4436             state_dict,
#    4437             loaded_keys,
#    4438             start_prefix,
#    4439             expected_keys,
#    4440             device_map=device_map,
#    4441             offload_folder=offload_folder,
#    4442             offload_index=offload_index,
#    4443             state_dict_folder=state_dict_folder,
#    4444             state_dict_index=state_dict_index,
#    4445             dtype=dtype,
#    4446             hf_quantizer=hf_quantizer,
#    4447             is_safetensors=is_safetensors,
#    4448             keep_in_fp32_modules=keep_in_fp32_modules,
#    4449             unexpected_keys=unexpected_keys,
#    4450         )
#    4451         error_msgs += new_error_msgs
#    4452 else:
#    4453     # Sharded checkpoint or whole but low_cpu_mem_usage==True
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:961, in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys, pretrained_model_name_or_path)
#     950     state_dict_index = offload_weight(param, param_name, state_dict_folder, state_dict_index)
#     951 elif (
#     952     not is_quantized
#     953     or (not hf_quantizer.requires_parameters_quantization)
#    (...)
#     959 ):
#     960     # For backward compatibility with older versions of `accelerate` and for non-quantized params
# --> 961     set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     962 else:
#     963     hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#
# File /usr/local/lib/python3.10/dist-packages/accelerate/utils/modeling.py:384, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     382             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     383 elif isinstance(value, torch.Tensor):
# --> 384     new_value = value.to(device)
#     385 else:
#     386     new_value = torch.tensor(value, device=device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 64.00 MiB. GPU 0 has a total capacity of 23.65 GiB of which 22.88 MiB is free. Process 3549849 has 18.19 GiB memory in use. Including non-PyTorch memory, this process has 5.40 GiB memory in use. Of the allocated memory 4.97 GiB is allocated by PyTorch, and 54.08 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
def compute_score(item,res):
    prompt = item['question']
    image = item['image'].resize((res, res), resample=Image.Resampling.LANCZOS).convert("RGB")
    image = image.resize((896, 896), resample=Image.Resampling.LANCZOS)
    model_inputs = processor(text=prompt, images=image, return_tensors="pt").to(model.device)
    input_len = model_inputs["input_ids"].shape[-1]
    with torch.inference_mode():
        generation = model.generate(**model_inputs, max_new_tokens=100, do_sample=False)
        generation = generation[0][input_len:]
        pred = processor.decode(generation, skip_special_tokens=True)
    score, _ = anls_score(item['answer'], pred, return_gt=True)
    return score, pred

# %%
scores = []
preds = []
qid = []
for res in [224,448,896]:
    scores.append([])
    preds.append([])
    qid.append([])
    for item in progress_bar(ds):
        score, pred = compute_score(item,res)
        scores[-1].append(score)
        preds[-1].append(pred)
        qid[-1].append(item['questionId'])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5188' class='' max='5188' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5188/5188 29:02&lt;00:00]
#     </div>
# /home/dgj335/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Attempt to open cnn_infer failed: handle=0 error: libcudnn_cnn_infer.so.8: cannot open shared object file: No such file or directory (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:78.)
#   return F.conv2d(input, weight, bias, self.stride,
# /home/dgj335/.local/lib/python3.10/site-packages/anls_star/anls_star.py:513: UserWarning: Treating ground truth as a list of options. This is a compatibility mode for ST-VQA-like datasets.
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5188' class='' max='5188' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5188/5188 29:23&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5188' class='' max='5188' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5188/5188 29:09&lt;00:00]
#     </div>

# %%
ds = ds.add_column('preds_16x',preds[0])
ds = ds.add_column('preds_4x',preds[1])
ds = ds.add_column('preds_1x',preds[2])

# %%
ds[3]
# Out:
# {'path': 'spdocvqa_images/hrfw0227_24.png',
#  'question': 'What is the personnel costs in the 4th year?',
#  'questionId': 61870,
#  'answer': ['Test server is available at rrc.cvc.uab.es'],
#  'image': <PIL.PngImagePlugin.PngImageFile image mode=L size=1784x2288>,
#  'preds_16x': '3,800',
#  'preds_4x': '21,720',
#  'preds_1x': '21,720'}

# %%
ds[3]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1784x2288>

# %%
ds.push_to_hub("danjacobellis/docvqa_paligemma896",split='test')
# Out:
# Uploading the dataset shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Map:   0%|          | 0/649 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/649 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/649 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/649 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/648 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/648 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/648 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Map:   0%|          | 0/648 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/danjacobellis/docvqa_paligemma896/commit/2ba200ec6c0c4457b3030b74583f9bfa6fd6c045', commit_message='Upload dataset', commit_description='', oid='2ba200ec6c0c4457b3030b74583f9bfa6fd6c045', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ---

# %%
# !wget https://hf.co/danjacobellis/walloc/resolve/main/RGB_Li_12c_J3_nf8_v1.0.2.pth

# %%
# !wget https://hf.co/danjacobellis/walloc/resolve/main/RGB_Li_48c_J3_nf8_v1.0.2.pth

# %%
# def walloc_compress(sample):
#     with torch.no_grad():
#         img = sample['image'].resize((896,896),resample=Image.Resampling.LANCZOS).convert("RGB")
#         x = PILToTensor()(img).to(torch.float)
#         x = (x/255 - 0.5).unsqueeze(0).to(device)
#         H, W = x.size(2), x.size(3)
#         x_padded = walloc.pad(x,p=8)
#         X = codec.wavelet_analysis(x_padded,codec.J)
#         Y = codec.encoder(X)
#         X_hat = codec.decoder(Y)
#         x_hat = codec.wavelet_synthesis(X_hat,codec.J)
#         x_hat = codec.clamp(x_hat)        
#         x_hat = walloc.crop(x_hat, (H,W))
#         rec = ToPILImage()(x_hat[0] + 0.5)
#         buff = io.BytesIO()
#         rec.save(buff, format='WEBP', lossless=True)
#         rec_webp_bytes = buff.getbuffer()   
        
#     return {
#         'recovered': rec_webp_bytes,
#     }

# %%
# device = "cuda"
# checkpoints = [
#     'RGB_Li_12c_J3_nf8_v1.0.2.pth',
#     'RGB_Li_48c_J3_nf8_v1.0.2.pth'
# ]
# fic_ds = []
# for cf in checkpoints:
#     checkpoint = torch.load(cf,map_location="cpu",weights_only=False)
#     codec_config = checkpoint['config']
#     codec = walloc.Codec2D(
#         channels = codec_config.channels,
#         J = codec_config.J,
#         Ne = codec_config.Ne,
#         Nd = codec_config.Nd,
#         latent_dim = codec_config.latent_dim,
#         latent_bits = codec_config.latent_bits,
#         lightweight_encode = codec_config.lightweight_encode
#     )
#     codec.load_state_dict(checkpoint['model_state_dict'])
#     codec = codec.to(device)
#     codec.eval();
#     fic_ds.append(
#         ds.map(walloc_compress).cast_column('recovered',HFImage())
#     )

# %%
# fic_ds = []
