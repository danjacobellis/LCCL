# %%
from IPython.display import Markdown, Latex
from datasets import load_dataset
import numpy as np
import pandas as pd

# %%
methods = [
    "danjacobellis/LSDIR_demucs_orig",
    "danjacobellis/LSDIR_demucs_2xRR",
    "danjacobellis/LSDIR_demucs_2x_walloc",
    "danjacobellis/LSDIR_demucs_5xRR",
    "danjacobellis/LSDIR_demucs_5x_walloc",
    "danjacobellis/LSDIR_demucs_10xRR",
    "danjacobellis/LSDIR_demucs_10x_walloc",
]

# %%
method_aggregated = {}

for method in methods:
    ds = load_dataset(method, split='validation')
    df = ds.to_pandas()
    method_aggregated[method] = df.mean()
# Out:
# README.md:   0%|          | 0.00/902 [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/50 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/902 [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/50 [00:00<?, ? examples/s]

# %%
results_df = pd.DataFrame(method_aggregated)
results_df = results_df.transpose()

# %%
results_df
# Out:
#                                        SSDR_other  SSDR_drums  SSDR_bass  \
# danjacobellis/LSDIR_demucs_orig         13.753074   22.302781  15.660749
# danjacobellis/LSDIR_demucs_2xRR         13.883515   19.460045  16.062864
# danjacobellis/LSDIR_demucs_2x_walloc    13.995920   17.338877  15.551265
# danjacobellis/LSDIR_demucs_5xRR         14.242777   16.007461  16.222297
# danjacobellis/LSDIR_demucs_5x_walloc    14.389502   16.241770  15.289354
# danjacobellis/LSDIR_demucs_10xRR        10.704823   16.199578  14.704946
# danjacobellis/LSDIR_demucs_10x_walloc   13.210964   15.545982  15.413898
#
#                                        SSDR_vocals  SRDR_other  SRDR_drums  \
# danjacobellis/LSDIR_demucs_orig          14.246989    5.007309    9.913120
# danjacobellis/LSDIR_demucs_2xRR          12.708179    4.994606    8.426462
# danjacobellis/LSDIR_demucs_2x_walloc     11.651202    4.316245    7.361906
# danjacobellis/LSDIR_demucs_5xRR          10.617006    4.215283    6.197284
# danjacobellis/LSDIR_demucs_5x_walloc     11.135118    4.027712    6.713292
# danjacobellis/LSDIR_demucs_10xRR          6.966281    2.198909    5.626160
# danjacobellis/LSDIR_demucs_10x_walloc     8.713092    2.591630    5.371202
#
#                                        SRDR_bass  SRDR_vocals  PSNR_other  \
# danjacobellis/LSDIR_demucs_orig         0.768342    -0.350839   37.382034
# danjacobellis/LSDIR_demucs_2xRR         0.655329    -1.130510   37.345101
# danjacobellis/LSDIR_demucs_2x_walloc    0.542824    -1.698209   36.728756
# danjacobellis/LSDIR_demucs_5xRR         0.788754    -2.502113   36.666770
# danjacobellis/LSDIR_demucs_5x_walloc   -0.135855    -2.275065   36.374665
# danjacobellis/LSDIR_demucs_10xRR       -1.134002    -6.824239   35.039341
# danjacobellis/LSDIR_demucs_10x_walloc  -0.345901    -4.613902   34.775065
#
#                                        PSNR_drums  PSNR_bass  PSNR_vocals  \
# danjacobellis/LSDIR_demucs_orig         40.244511  40.930796    41.371783
# danjacobellis/LSDIR_demucs_2xRR         39.134829  41.124241    40.735187
# danjacobellis/LSDIR_demucs_2x_walloc    38.318439  41.049592    40.152142
# danjacobellis/LSDIR_demucs_5xRR         37.757372  41.110500    39.719983
# danjacobellis/LSDIR_demucs_5x_walloc    37.858339  40.890640    39.673793
# danjacobellis/LSDIR_demucs_10xRR        37.322374  40.381729    37.350482
# danjacobellis/LSDIR_demucs_10x_walloc   37.343891  39.475253    38.148983
#
#                                        CDPAM_dB_other  CDPAM_dB_drums  \
# danjacobellis/LSDIR_demucs_orig              4.705127        4.786927
# danjacobellis/LSDIR_demucs_2xRR              4.693773        4.460550
# danjacobellis/LSDIR_demucs_2x_walloc         4.750398        4.272236
# danjacobellis/LSDIR_demucs_5xRR              4.714108        4.125149
# danjacobellis/LSDIR_demucs_5x_walloc         4.734882        4.175864
# danjacobellis/LSDIR_demucs_10xRR             4.355985        4.126468
# danjacobellis/LSDIR_demucs_10x_walloc        4.582460        4.108161
#
#                                        CDPAM_dB_bass  CDPAM_dB_vocals
# danjacobellis/LSDIR_demucs_orig             4.951358         4.920378
# danjacobellis/LSDIR_demucs_2xRR             5.002654         4.772007
# danjacobellis/LSDIR_demucs_2x_walloc        4.970598         4.660038
# danjacobellis/LSDIR_demucs_5xRR             4.991243         4.554649
# danjacobellis/LSDIR_demucs_5x_walloc        4.946015         4.616613
# danjacobellis/LSDIR_demucs_10xRR            4.931243         4.275728
# danjacobellis/LSDIR_demucs_10x_walloc       4.833813         4.511948

# %%
print(results_df.to_markdown())
# Out:
# |                                       |   SSDR_other |   SSDR_drums |   SSDR_bass |   SSDR_vocals |   SRDR_other |   SRDR_drums |   SRDR_bass |   SRDR_vocals |   PSNR_other |   PSNR_drums |   PSNR_bass |   PSNR_vocals |   CDPAM_dB_other |   CDPAM_dB_drums |   CDPAM_dB_bass |   CDPAM_dB_vocals |
# |:--------------------------------------|-------------:|-------------:|------------:|--------------:|-------------:|-------------:|------------:|--------------:|-------------:|-------------:|------------:|--------------:|-----------------:|-----------------:|----------------:|------------------:|
# | danjacobellis/LSDIR_demucs_orig       |      13.7531 |      22.3028 |     15.6607 |      14.247   |      5.00731 |      9.91312 |    0.768342 |     -0.350839 |      37.382  |      40.2445 |     40.9308 |       41.3718 |          4.70513 |          4.78693 |         4.95136 |           4.92038 |
# | danjacobellis/LSDIR_demucs_2xRR       |      13.8835 |      19.46   |     16.0629 |      12.7082  |      4.99461 |      8.42646 |    0.655329 |     -1.13051  |      37.3451 |      39.1348 |     41.1242 |       40.7352 |          4.69377 |          4.46055 |         5.00265 |           4.77201 |
# | danjacobellis/LSDIR_demucs_2x_walloc  |      13.9959 |      17.3389 |     15.5513 |      11.6512  |      4.31624 |      7.36191 |    0.542824 |     -1.69821  |      36.7288 |      38.3184 |     41.0496 |       40.1521 |          4.7504  |          4.27224 |         4.9706  |           4.66004 |
# | danjacobellis/LSDIR_demucs_5xRR       |      14.2428 |      16.0075 |     16.2223 |      10.617   |      4.21528 |      6.19728 |    0.788754 |     -2.50211  |      36.6668 |      37.7574 |     41.1105 |       39.72   |          4.71411 |          4.12515 |         4.99124 |           4.55465 |
# | danjacobellis/LSDIR_demucs_5x_walloc  |      14.3895 |      16.2418 |     15.2894 |      11.1351  |      4.02771 |      6.71329 |   -0.135855 |     -2.27506  |      36.3747 |      37.8583 |     40.8906 |       39.6738 |          4.73488 |          4.17586 |         4.94602 |           4.61661 |
# | danjacobellis/LSDIR_demucs_10xRR      |      10.7048 |      16.1996 |     14.7049 |       6.96628 |      2.19891 |      5.62616 |   -1.134    |     -6.82424  |      35.0393 |      37.3224 |     40.3817 |       37.3505 |          4.35598 |          4.12647 |         4.93124 |           4.27573 |
# | danjacobellis/LSDIR_demucs_10x_walloc |      13.211  |      15.546  |     15.4139 |       8.71309 |      2.59163 |      5.3712  |   -0.345901 |     -4.6139   |      34.7751 |      37.3439 |     39.4753 |       38.149  |          4.58246 |          4.10816 |         4.83381 |           4.51195 |

# %%
metrics = ['SSDR', 'SRDR', 'PSNR', 'CDPAM_dB']
instruments = ['other', 'drums', 'bass', 'vocals']
df_metrics = pd.DataFrame(index=results_df.index)
for metric in metrics:
    cols = [f"{metric}_{instrument}" for instrument in instruments]
    df_metrics[metric] = results_df[cols].mean(axis=1)

# %%
df_metrics
# Out:
#                                             SSDR      SRDR       PSNR  \
# danjacobellis/LSDIR_demucs_orig        16.490898  3.834483  39.982281
# danjacobellis/LSDIR_demucs_2xRR        15.528651  3.236472  39.584839
# danjacobellis/LSDIR_demucs_2x_walloc   14.634316  2.630692  39.062232
# danjacobellis/LSDIR_demucs_5xRR        14.272385  2.174802  38.813656
# danjacobellis/LSDIR_demucs_5x_walloc   14.263936  2.082521  38.699359
# danjacobellis/LSDIR_demucs_10xRR       12.143907 -0.033293  37.523481
# danjacobellis/LSDIR_demucs_10x_walloc  13.220984  0.750757  37.435798
#
#                                        CDPAM_dB
# danjacobellis/LSDIR_demucs_orig        4.840948
# danjacobellis/LSDIR_demucs_2xRR        4.732246
# danjacobellis/LSDIR_demucs_2x_walloc   4.663318
# danjacobellis/LSDIR_demucs_5xRR        4.596287
# danjacobellis/LSDIR_demucs_5x_walloc   4.618344
# danjacobellis/LSDIR_demucs_10xRR       4.422356
# danjacobellis/LSDIR_demucs_10x_walloc  4.509095

# %%
scores = pd.DataFrame(index=results_df.index, columns=['other', 'drums', 'bass', 'vocals'])
instruments = ['other', 'drums', 'bass', 'vocals']
metrics = ['SSDR', 'SRDR', 'PSNR', 'CDPAM_dB']

# Compute scores
for instrument in instruments:
    total_weights = 0
    score = pd.Series(0, index=results_df.index)
    for metric in metrics:
        metric_name = f'{metric}_{instrument}'
        first_row_value = results_df.loc['danjacobellis/LSDIR_demucs_orig', metric_name]
        
        # Skip if the first row value is zero or negative (to avoid division by zero or negative weights)
        if first_row_value <= 0:
            continue
        
        weight = 0.25 / first_row_value
        total_weights += weight
        
        # Calculate the weighted metric for each model
        score += weight * results_df[metric_name]
    
    # Normalize the score to ensure the original signal has a score of 1
    score /= score.loc['danjacobellis/LSDIR_demucs_orig']
    scores[instrument] = score.round(4)

# %%
scores
# Out:
#                                         other   drums    bass  vocals
# danjacobellis/LSDIR_demucs_orig        1.0000  1.0000  1.0000  1.0000
# danjacobellis/LSDIR_demucs_2xRR        1.0009  0.9067  0.9734  0.9488
# danjacobellis/LSDIR_demucs_2x_walloc   0.9679  0.8412  0.9266  0.9118
# danjacobellis/LSDIR_demucs_5xRR        0.9651  0.7857  1.0187  0.8770
# danjacobellis/LSDIR_demucs_5x_walloc   0.9575  0.8046  0.6994  0.8929
# danjacobellis/LSDIR_demucs_10xRR       0.7702  0.7708  0.3614  0.7536
# danjacobellis/LSDIR_demucs_10x_walloc  0.8456  0.7562  0.6187  0.8169

# %%
df_combined = pd.concat([scores, df_metrics], axis=1)
cols = df_combined.columns.tolist()
cols.insert(3, cols.pop(0))
df_combined = df_combined[cols]

# %%
df_combined
# Out:
#                                         drums    bass  vocals   other  \
# danjacobellis/LSDIR_demucs_orig        1.0000  1.0000  1.0000  1.0000
# danjacobellis/LSDIR_demucs_2xRR        0.9067  0.9734  0.9488  1.0009
# danjacobellis/LSDIR_demucs_2x_walloc   0.8412  0.9266  0.9118  0.9679
# danjacobellis/LSDIR_demucs_5xRR        0.7857  1.0187  0.8770  0.9651
# danjacobellis/LSDIR_demucs_5x_walloc   0.8046  0.6994  0.8929  0.9575
# danjacobellis/LSDIR_demucs_10xRR       0.7708  0.3614  0.7536  0.7702
# danjacobellis/LSDIR_demucs_10x_walloc  0.7562  0.6187  0.8169  0.8456
#
#                                             SSDR      SRDR       PSNR  \
# danjacobellis/LSDIR_demucs_orig        16.490898  3.834483  39.982281
# danjacobellis/LSDIR_demucs_2xRR        15.528651  3.236472  39.584839
# danjacobellis/LSDIR_demucs_2x_walloc   14.634316  2.630692  39.062232
# danjacobellis/LSDIR_demucs_5xRR        14.272385  2.174802  38.813656
# danjacobellis/LSDIR_demucs_5x_walloc   14.263936  2.082521  38.699359
# danjacobellis/LSDIR_demucs_10xRR       12.143907 -0.033293  37.523481
# danjacobellis/LSDIR_demucs_10x_walloc  13.220984  0.750757  37.435798
#
#                                        CDPAM_dB
# danjacobellis/LSDIR_demucs_orig        4.840948
# danjacobellis/LSDIR_demucs_2xRR        4.732246
# danjacobellis/LSDIR_demucs_2x_walloc   4.663318
# danjacobellis/LSDIR_demucs_5xRR        4.596287
# danjacobellis/LSDIR_demucs_5x_walloc   4.618344
# danjacobellis/LSDIR_demucs_10xRR       4.422356
# danjacobellis/LSDIR_demucs_10x_walloc  4.509095

# %%
df_rounded = df_combined.round(5)
column_format = 'l' + 'rr' * len(metrics)
latex_table = df_rounded.to_latex(
    index=True,
    float_format="%.3g",
    column_format=column_format,
    multicolumn=True,
    multicolumn_format='c',
    bold_rows=True
)
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & drums & bass & vocals & other & SSDR & SRDR & PSNR & CDPAM_dB \\
# \midrule
# \textbf{danjacobellis/LSDIR_demucs_orig} & 1 & 1 & 1 & 1 & 16.5 & 3.83 & 40 & 4.84 \\
# \textbf{danjacobellis/LSDIR_demucs_2xRR} & 0.907 & 0.973 & 0.949 & 1 & 15.5 & 3.24 & 39.6 & 4.73 \\
# \textbf{danjacobellis/LSDIR_demucs_2x_walloc} & 0.841 & 0.927 & 0.912 & 0.968 & 14.6 & 2.63 & 39.1 & 4.66 \\
# \textbf{danjacobellis/LSDIR_demucs_5xRR} & 0.786 & 1.02 & 0.877 & 0.965 & 14.3 & 2.17 & 38.8 & 4.6 \\
# \textbf{danjacobellis/LSDIR_demucs_5x_walloc} & 0.805 & 0.699 & 0.893 & 0.958 & 14.3 & 2.08 & 38.7 & 4.62 \\
# \textbf{danjacobellis/LSDIR_demucs_10xRR} & 0.771 & 0.361 & 0.754 & 0.77 & 12.1 & -0.0333 & 37.5 & 4.42 \\
# \textbf{danjacobellis/LSDIR_demucs_10x_walloc} & 0.756 & 0.619 & 0.817 & 0.846 & 13.2 & 0.751 & 37.4 & 4.51 \\
# \bottomrule
# \end{tabular}
