# %%
import PIL
from datasets import load_dataset
from IPython.display import display

# %%
cheng2020 = load_dataset("danjacobellis/LSDIR_DGML_q6", split='validation')
walloc_4x = load_dataset("danjacobellis/LSDIR_RGB_Li_48c_J3_nf8", split='validation')
sd3 = load_dataset("danjacobellis/LSDIR_stable_diffusion_3_fp16",split='validation')
walloc_16x = load_dataset("danjacobellis/LSDIR_RGB_Li_12c_J3_nf8", split='validation')

# %%
cheng2020[28]
# Out:
# {'path': 'LSDIR_val/val1/HR/val/0000123.png',
#  'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1980x1320>,
#  'w': 1980,
#  'h': 1320,
#  'mode': 'RGB',
#  'aspect': 1.5,
#  'n_pixels': 2613600,
#  'recovered': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1980x1320>,
#  'cpu_encode_time': 7.126707077026367,
#  'cpu_decode_time': 16.052342176437378,
#  'bpp': 0.6092684419957147,
#  'PSNR': 35.79001998901367,
#  'MSSIM': 0.9873216152191162,
#  'LPIPS_dB': 6.903146144619885,
#  'DISTS_dB': 15.518982013856217}

# %%
walloc_4x[28]
# Out:
# {'path': 'LSDIR_val/val1/HR/val/0000123.png',
#  'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1980x1320>,
#  'w': 1980,
#  'h': 1320,
#  'mode': 'RGB',
#  'aspect': 1.5,
#  'n_pixels': 2613600,
#  'recovered': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1980x1320>,
#  'compressed': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=992x664>,
#  'encode_time': 0.14242815971374512,
#  'decode_time': 0.014560937881469727,
#  'bpp': 2.3674380165289257,
#  'PSNR': 34.31401443481445,
#  'MSSIM': 0.987437903881073,
#  'LPIPS_dB': 10.173417247593674,
#  'DISTS_dB': 19.925321727872078,
#  'cpu_encode_time': 0.23181724548339844,
#  'cpu_decode_time': 7.489074468612671}

# %%
sd3_metrics = sd3[28]
del sd3_metrics['compressed']
sd3_metrics
# Out:
# {'path': 'LSDIR_val/val1/HR/val/0000123.png',
#  'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1980x1320>,
#  'w': 1980,
#  'h': 1320,
#  'mode': 'RGB',
#  'aspect': 1.5,
#  'n_pixels': 2613600,
#  'recovered': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1980x1320>,
#  'encode_time': 0.45861387252807617,
#  'decode_time': 0.007162332534790039,
#  'bpp': 4.0,
#  'PSNR': 21.965559005737305,
#  'MSSIM': 0.8863414525985718,
#  'LPIPS_dB': 8.143260228007428,
#  'DISTS_dB': 13.850765841361014,
#  'cpu_encode_time': 13.369189977645874,
#  'cpu_decode_time': 25.35370135307312}

# %%
walloc_16x[28]
# Out:
# {'path': 'LSDIR_val/val1/HR/val/0000123.png',
#  'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1980x1320>,
#  'w': 1980,
#  'h': 1320,
#  'mode': 'RGB',
#  'aspect': 1.5,
#  'n_pixels': 2613600,
#  'recovered': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1980x1320>,
#  'compressed': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=496x332>,
#  'encode_time': 0.043805837631225586,
#  'decode_time': 0.0075910091400146484,
#  'bpp': 0.5611202938475666,
#  'PSNR': 30.63683319091797,
#  'MSSIM': 0.9723321795463562,
#  'LPIPS_dB': 6.45252935393137,
#  'DISTS_dB': 14.693924437668251,
#  'cpu_encode_time': 0.1428356170654297,
#  'cpu_decode_time': 7.389040231704712}

# %%
for ds in [cheng2020,walloc_4x,sd3,walloc_16x]:
    img = ds[28]['recovered']
    display(img)

# %%
for ds in [cheng2020,walloc_4x,sd3,walloc_16x]:
    img = ds[28]['recovered']
    display(img.crop([1365,675,1425,750]).resize((6*60,6*75),resample=PIL.Image.Resampling.LANCZOS))
# Out:
# <PIL.Image.Image image mode=RGB size=360x450>
# <PIL.Image.Image image mode=RGB size=360x450>
# <PIL.Image.Image image mode=RGB size=360x450>
# <PIL.Image.Image image mode=RGB size=360x450>
